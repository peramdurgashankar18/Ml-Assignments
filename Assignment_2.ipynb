# %% [markdown]
# <a href="https://colab.research.google.com/github/peramdurgashankar18/Ml-Assignments/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment-2

# %%
import pandas as pd

# %% [markdown]
# 1.**bold text** Create a Pandas DataFrame from the following dictionary:
#
#
#
#       data = {
#       'Name': ['Alice', 'Bob', 'Carol'],
#       'Age': [24, 27, 22],
#       'Salary': [50000, 55000, 48000]
#       }
# • Add a new column called Bonus which is 10% of the salary

# %%
data = {'Name': ['Alice', 'Bob', 'Carol'], 'Age': [24, 27, 22], 'Salary': [50000, 55000, 48000]}
df = pd.DataFrame(data)
df['Bonus'] = 0.1 * df['Salary']
df
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0

# %% [markdown]
# 2. Given the DataFrame created in the above question:
# • Display the first two rows.
# • Compute the mean salary
#
#
#     print(df.head(2))
#     mean_salary = df['Salary'].mean()
#     print(mean_salary)

# %%
print(df.head(2))
mean_salary = df['Salary'].mean()
print(mean_salary)
# Out:
#     Name  Age  Salary
# 0  Alice   24   48000
# 1    Bob   27   54000
# 52200.0

# %% [markdown]
# 3.Using the same DataFrame:
# • Extract all rows where the Age is greater than 25.
# • Filter out rows where the Salary is less than 50000
#
#
#     data = {
#     'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
#     'Age': [24, 27, 22, 32, 29],
#     'Salary': [48000, 54000, 52000, 62000, 45000]
#     }
#     df = pd.DataFrame(data)
#     age_filtered = df[df['Age'] > 25]
#     salary_filtered = age_filtered[age_filtered['Salary'] < 50000]
#     print(salary_filtered)

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [24, 27, 22, 32, 29],
    'Salary': [48000, 54000, 52000, 62000, 45000]
}
df = pd.DataFrame(data)
age_filtered = df[df['Age'] > 25]
salary_filtered = age_filtered[age_filtered['Salary'] < 50000]
print(salary_filtered)
# Out:
#   Name  Age  Salary
# 4  Eve   29   45000

# %% [markdown]
# 4.Create the following DataFrame:
# data = {
#  'A': [1, 2, None, 4],
#  'B': [None, 2, 3, None],
#  'C': [1, 2, 3, 4]
# }
# df = pd.DataFrame(data)
# • Fill missing values in column A with the mean of the column.
# • Drop rows where all values are None.
#
#     data = {'A': [1, 2, None, 4], 'B': [None, 2, 3, None], 'C': [1, 2, 3, 4]}
#     df = pd.DataFrame(data)
#     df['A'].fillna(df['A'].mean(), inplace=True)
#     df = df.dropna(how='all')
#     df

# %%
data = {'A': [1, 2, None, 4], 'B': [None, 2, 3, None], 'C': [1, 2, 3, 4]}
df = pd.DataFrame(data)
df['A'].fillna(df['A'].mean(), inplace=True)
df = df.dropna(how='all')
df
# Out:
# <ipython-input-9-95086c52403b>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(df['A'].mean(), inplace=True)
#           A    B  C
# 0  1.000000  NaN  1
# 1  2.000000  2.0  2
# 2  2.333333  3.0  3
# 3  4.000000  NaN  4

# %% [markdown]
# 5.Create a DataFrame for employees:
# data = {
#  'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
#  'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
#  'Salary': [50000, 45000, 60000, 65000, 70000]
# }
# • Group the data by Department and compute the total and mean salary for each
# department
#
#     data = {
#     'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
#     'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
#     'Salary': [50000, 45000, 60000, 65000, 70000]
#     }
#     df = pd.DataFrame(data)
#     grouped = df.groupby('Department')
#     total_salary = grouped['Salary'].sum()
#     mean_salary = grouped['Salary'].mean()
#     print(total_salary)
#     print(mean_salary)

# %%
data = {
    'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
    'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Salary': [50000, 45000, 60000, 65000, 70000]
}
df = pd.DataFrame(data)
grouped = df.groupby('Department')
total_salary = grouped['Salary'].sum()
mean_salary = grouped['Salary'].mean()
print(total_salary)
print(mean_salary)
# Out:
# Department
# Finance     70000
# HR          95000
# IT         125000
# Name: Salary, dtype: int64
# Department
# Finance    70000.0
# HR         47500.0
# IT         62500.0
# Name: Salary, dtype: float64

# %% [markdown]
# 6.Given two DataFrames:
# df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
# df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
# • Perform an inner join on the ID column.
#
#     df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
#     df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
#     inner_join = pd.merge(df1, df2, on='ID', how='inner')
#     print(inner_join)

# %%
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
inner_join = pd.merge(df1, df2, on='ID', how='inner')
print(inner_join)
# Out:
#    ID   Name  Age
# 0   2    Bob   25
# 1   3  Carol   30

# %% [markdown]
# 7.Given a small dataset, clean and display basic statistics using Pandas
#
#     df3 = pd.DataFrame(data)
#     df3.describe()

# %%
df3 = pd.DataFrame(data)
df3.describe()
# Out:
#               A         B          C
# count  3.000000  3.000000   4.000000
# mean   2.333333  6.666667  10.500000
# std    1.527525  1.527525   1.290994
# min    1.000000  5.000000   9.000000
# 25%    1.500000  6.000000   9.750000
# 50%    2.000000  7.000000  10.500000
# 75%    3.000000  7.500000  11.250000
# max    4.000000  8.000000  12.000000

# %% [markdown]
# 8. small EDA task
# • Load the Titanic dataset (titanic.csv) into a Pandas DataFrame.
# • Perform the following tasks:
# o Display the number of missing values in each column.
# o Find the average age of passengers.
# o Create a bar plot to show the survival rate based on gender.
#
#         titanic_df = pd.read_csv('/Titanic-Dataset.csv')
#         missing_values = titanic_df.isnull().sum()
#         print(missing_values)
#         average_age = titanic_df['Age'].mean()
#         print(average_age)

# %%
titanic_df = pd.read_csv('/Titanic-Dataset.csv')
missing_values = titanic_df.isnull().sum()
print(missing_values)
average_age = titanic_df['Age'].mean()
print(average_age)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# 29.69911764705882

# %% [markdown]
# 9.Data Transformation
# • Load a dataset containing daily temperatures and dates. Perform the following:
# o Convert the date column into a DateTime object.
# o Create a new column that categorizes temperatures into High, Medium, or
# Low

# %%
df4 = pd.read_csv('/daily-min-temperatures.csv')
df4['Date'] = pd.to_datetime(df4['Date'])
df4
# Out:
#            Date  Temp
# 0    1981-01-01  20.7
# 1    1981-01-02  17.9
# 2    1981-01-03  18.8
# 3    1981-01-04  14.6
# 4    1981-01-05  15.8
# ...         ...   ...
# 3645 1990-12-27  14.0
# 3646 1990-12-28  13.6
# 3647 1990-12-29  13.5
# 3648 1990-12-30  15.7
# 3649 1990-12-31  13.0
#
# [3650 rows x 2 columns]
